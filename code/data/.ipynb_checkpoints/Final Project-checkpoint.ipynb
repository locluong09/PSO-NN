# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
field_data = pd.read_excel("finalproject_data.xlsx", sheet_name = 0, hearder = 0)

# %%
reservoir_parameters = pd.read_excel("finalproject_data.xlsx", sheet_name = 1, header = 3, usecols = "B:GG")

# %%
reservoir_parameters
# Out:
#    Parameter/cases     Case 1     Case 2     Case 3     Case 4      Case 5  \
# 0      Parameter 1  64.780313  31.254738  44.316630  54.910794  144.830271
# 1      Parameter 2   0.071322   0.229573   0.175438   0.093901    0.319099
# 2      Parameter 3   0.219026   0.159058   0.310606   0.198274    0.124092
# 3      Parameter 4   0.290827   0.201507   0.215980   0.191163    0.150389
# 4      Parameter 5   0.091782   0.081371   0.020669   0.087844    0.035817
# 5      Parameter 6   4.343132   4.705390   2.135252   3.812632    5.279040
# 6      Parameter 7   3.118870   5.686810   2.902780   5.861635    1.116532
# 7      Parameter 8   2.108335   2.859026   3.573910   1.156175    6.295279
# 8      Parameter 9   2.639732   6.831181   2.189828   4.516895    3.370739
# 9     Parameter 10   0.816774   0.614802   0.471443   0.522479    0.374583
# 10    Parameter 11   0.836320   0.999727   0.886245   0.545539    0.776431
# ...

# %%
simulation_cases = pd.read_excel("finalproject_data.xlsx", sheet_name = 2, header = 0)

# %%
field_data.columns = ["Years", "Oil rate"]

# %%
field_data.drop([0], axis = 0, inplace = True)

# %%
field_data.to_csv("field_data.csv", columns = ["Oil rate"])

# %%
reservoir_parameters.drop(["Parameter/cases"], axis = 1, inplace = True)

# %%
reservoir_parameters
# Out:
#        Case 1     Case 2     Case 3     Case 4      Case 5     Case 6  \
# 0   64.780313  31.254738  44.316630  54.910794  144.830271  78.089969
# 1    0.071322   0.229573   0.175438   0.093901    0.319099   0.102961
# 2    0.219026   0.159058   0.310606   0.198274    0.124092   0.085414
# 3    0.290827   0.201507   0.215980   0.191163    0.150389   0.161643
# 4    0.091782   0.081371   0.020669   0.087844    0.035817   0.016789
# 5    4.343132   4.705390   2.135252   3.812632    5.279040   4.935734
# 6    3.118870   5.686810   2.902780   5.861635    1.116532   3.852000
# 7    2.108335   2.859026   3.573910   1.156175    6.295279   4.070333
# 8    2.639732   6.831181   2.189828   4.516895    3.370739   3.422092
# 9    0.816774   0.614802   0.471443   0.522479    0.374583   0.890866
# 10   0.836320   0.999727   0.886245   0.545539    0.776431   0.748968
# 11   0.994869   0.818324   0.821676   0.836730    0.922441   0.939074
# ...

# %%
reservoir_parameters.to_csv("reservoir_parameters.csv")

# %%
simulation_cases.drop(["Case/Time"], axis = 1, inplace = True)
simulation_cases.to_csv("simulation_cases.csv")
